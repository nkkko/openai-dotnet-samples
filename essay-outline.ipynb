# %% [markdown]
# # Essay outline
#
# Generate an outline for a research topic.
#
# ## Settings
#
# | Setting | Value |
# | --- | --- |
# | Model | gpt-35-turbo-instruct |
# | Max tokens | 150 |
# | Temperature | 0.3 |
# | Top p | 1 |
# | Frequency penalty | 0.0 |
# | Presence penalty | 0.0 |
#
# ## Prompt
#
# ```text
# Create an outline for an essay about Nikola Tesla and his contributions to technology:
# ```

# %% [markdown]
# ## Install Azure OpenAI Service .NET SDK
#
# [Azure.AI.OpenAI NuGet package](https://www.nuget.org/packages/Azure.AI.OpenAI/)

# %%
#r "nuget: Azure.AI.OpenAI, 1.0.0-beta.15"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.AI.OpenAI, 1.0.0-beta.15</span></li></ul></div></div>

# %%
using System;
using Azure.AI.OpenAI;

# %% [markdown]
# ## Configure Azure OpenAI client

# %%
var AOAI_ENDPOINT = Environment.GetEnvironmentVariable("AOAI_ENDPOINT");
var AOAI_KEY = Environment.GetEnvironmentVariable("AOAI_KEY");
var AOAI_DEPLOYMENTID = Environment.GetEnvironmentVariable("AOAI_DEPLOYMENTID");

# %%
var endpoint = new Uri(AOAI_ENDPOINT);
var credentials = new Azure.AzureKeyCredential(AOAI_KEY);
var openAIClient = new OpenAIClient(endpoint, credentials);

# %% [markdown]
# ## Define prompt

# %%
var prompt = 
    """
    Create an outline for an essay about Nikola Tesla and his contributions to technology:
    """;

# %% [markdown]
# ## Configure completion options

# %%
var completionOptions = new CompletionsOptions
{
    DeploymentName=AOAI_DEPLOYMENTID,
    MaxTokens=150,
    Temperature=0.3f,
    FrequencyPenalty=0.0f,
    PresencePenalty=0.0f,
};

completionOptions.Prompts.Add(prompt);

# %% [markdown]
# ## Generate completions

# %%
Completions response = await openAIClient.GetCompletionsAsync(completionOptions);

# %%
response.Choices[0].Text
# Out:
# I. Introduction
#     A. Background information on Nikola Tesla
#     B. Thesis statement: Nikola Tesla's contributions to technology revolutionized the modern world.
#
# II. Early Life and Education
#     A. Family background and childhood
#     B. Education and early interests in science and technology
#     C. Move to the United States and work with Thomas Edison
#
# III. Inventions and Discoveries
#     A. Alternating current (AC) electricity
#         1. Advantages over direct current (DC)
#         2. Impact on the modern world
#     B. Tesla coil
#         1. Function and uses
#         2. Influence on wireless technology
#     C. Other inventions and discoveries
#         1. Radio
